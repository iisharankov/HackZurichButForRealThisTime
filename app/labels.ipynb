# %%
import pandas as pd
import matplotlib.pyplot as plt

import labels

# %%
labels_df = labels.load_labels()
labels_df
# Out:
#                      filename  sensitive                  name extension
# 0         within-resource.xml       True       within-resource       xml
# 1         fly-camera-book.xml       True       fly-camera-book       xml
# 2        illo-id-et-ullam.jpg       True      illo-id-et-ullam       jpg
# 3       voluptatem-minima.jpg       True     voluptatem-minima       jpg
# 4                 debitis.msg       True               debitis       msg
# ..                        ...        ...                   ...       ...
# 843          escrow-ether.png       True          escrow-ether       png
# 844  export-t12-teneighty.jpg       True  export-t12-teneighty       jpg
# 845          huber-muster.png       True          huber-muster       png
# 846           meta-export.jpg       True           meta-export       jpg
# 847           meta-object.jpg       True           meta-object       jpg
#
# [848 rows x 4 columns]

# %%
summary = labels.create_summary()
summary
# Out:
#    extension  count  frequency  perc sensitive
# 0        pdf    105   0.123821        0.476190
# 1       xlsx    101   0.119104        0.108911
# 2        log    100   0.117925        0.010000
# 3        csv     99   0.116745        0.111111
# 4         md     66   0.077830        0.196970
# 5       html     60   0.070755        0.050000
# 6        pem     57   0.067217        1.000000
# 7      weird     55   0.064858        0.163636
# 8        ps1     48   0.056604        0.333333
# 9        pub     41   0.048349        0.121951
# 10        db     20   0.023585        0.200000
# 11       xml     19   0.022406        0.105263
# 12       png     12   0.014151        0.250000
# 13      docx     12   0.014151        0.500000
# 14       jpg     10   0.011792        0.600000
# 15        py     10   0.011792        0.100000
# 16       txt     10   0.011792        0.100000
# 17       zip     10   0.011792        0.100000
# 18       msg      7   0.008255        0.285714
# ...

# %%
summary.plot("extension", y = ["frequency", "perc sensitive"], kind = "bar", alpha=0.7)
# Out:
# <Axes: xlabel='extension'>
